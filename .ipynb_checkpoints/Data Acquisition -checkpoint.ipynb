# %%
import pandas as pd
import numpy as np

# %%
import os
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\GerardEspejo\\Desktop\\TFM\\TFM'

# %%
df = pd.read_csv('C:\\Users\\GerardEspejo\\Desktop\\TFM\\Data\\Reporting Carrier On-Time Performance.csv')
df.head()
# Out:
#    YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 0  2018        1      1            27            6  2018-01-27
# 1  2018        1      1            27            6  2018-01-27
# 2  2018        1      1            27            6  2018-01-27
# 3  2018        1      1            27            6  2018-01-27
# 4  2018        1      1            27            6  2018-01-27
#
#   OP_UNIQUE_CARRIER OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM     ...      \
# 0                UA         UA   N26232                369     ...
# 1                UA         UA   N477UA                368     ...
# 2                UA         UA   N13720                367     ...
# 3                UA         UA   N16217                366     ...
# 4                UA         UA   N33714                365     ...
#
#    AIR_TIME  FLIGHTS DISTANCE DISTANCE_GROUP CARRIER_DELAY  WEATHER_DELAY  \
# 0     148.0      1.0    966.0              4           NaN            NaN
# 1      98.0      1.0    679.0              3           NaN            NaN
# 2     190.0      1.0   1208.0              5           NaN            NaN
# 3     212.0      1.0   1744.0              7           NaN            NaN
# 4     112.0      1.0    820.0              4           NaN            NaN
#
#    NAS_DELAY  SECURITY_DELAY LATE_AIRCRAFT_DELAY Unnamed: 48
# 0        NaN             NaN                 NaN         NaN
# 1        NaN             NaN                 NaN         NaN
# 2        NaN             NaN                 NaN         NaN
# 3        NaN             NaN                 NaN         NaN
# 4        NaN             NaN                 NaN         NaN
#
# [5 rows x 49 columns]

# %%
df.columns
# Out:
# Index(['YEAR', 'QUARTER', 'MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'FL_DATE',
#        'OP_UNIQUE_CARRIER', 'OP_CARRIER', 'TAIL_NUM', 'OP_CARRIER_FL_NUM',
#        'ORIGIN_AIRPORT_ID', 'ORIGIN_CITY_MARKET_ID', 'ORIGIN',
#        'ORIGIN_STATE_ABR', 'ORIGIN_STATE_NM', 'ORIGIN_WAC', 'DEST_AIRPORT_ID',
#        'DEST_CITY_MARKET_ID', 'DEST', 'DEST_STATE_ABR', 'DEST_STATE_NM',
#        'DEST_WAC', 'CRS_DEP_TIME', 'DEP_TIME', 'DEP_DELAY', 'DEP_DELAY_NEW',
#        'DEP_DEL15', 'DEP_DELAY_GROUP', 'CRS_ARR_TIME', 'ARR_TIME', 'ARR_DELAY',
#        'ARR_DELAY_NEW', 'ARR_DEL15', 'ARR_DELAY_GROUP', 'CANCELLED',
#        'CANCELLATION_CODE', 'DIVERTED', 'CRS_ELAPSED_TIME',
#        'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'FLIGHTS', 'DISTANCE',
#        'DISTANCE_GROUP', 'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY',
#        'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY', 'Unnamed: 48'],
#       dtype='object')

# %%
df_flights_list = df[['YEAR', 'FL_DATE', 'ORIGIN_AIRPORT_ID', 'ORIGIN', 'DEST_AIRPORT_ID', 'DEST', 'DEP_DELAY', 'ARR_DELAY', 'CANCELLED']]
df_flights_list.head(10)
# Out:
#    YEAR     FL_DATE  ORIGIN_AIRPORT_ID ORIGIN  DEST_AIRPORT_ID DEST  \
# 0  2018  2018-01-27              11697    FLL            12266  IAH
# 1  2018  2018-01-27              14747    SEA            14771  SFO
# 2  2018  2018-01-27              11278    DCA            12266  IAH
# 3  2018  2018-01-27              12892    LAX            13930  ORD
# 4  2018  2018-01-27              12451    JAX            11618  EWR
# 5  2018  2018-01-27              12266    IAH            14107  PHX
# 6  2018  2018-01-27              11618    EWR            12173  HNL
# 7  2018  2018-01-27              12173    HNL            11618  EWR
# 8  2018  2018-01-27              12889    LAS            14771  SFO
# 9  2018  2018-01-27              12264    IAD            15304  TPA
#
#    DEP_DELAY  ARR_DELAY  CANCELLED
# 0      -13.0      -12.0        0.0
# 1       -4.0      -18.0        0.0
# 2       -2.0        1.0        0.0
# 3       -9.0       -8.0        0.0
# 4      -14.0      -24.0        0.0
# 5       -7.0      -19.0        0.0
# 6       27.0       19.0        0.0
# 7        8.0      -23.0        0.0
# 8       -5.0      -22.0        0.0
# 9       -7.0      -18.0        0.0

# %%
max_delay_mins = df_flights_list[['DEP_DELAY']].max()
max_delay_hours = max_delay_mins/60
max_delay_hours
# Out:
# DEP_DELAY    33.45
# dtype: float64

# %%
df_flights_list.sort_values(by=['DEP_DELAY'])
# Out:
#         YEAR     FL_DATE  ORIGIN_AIRPORT_ID ORIGIN  DEST_AIRPORT_ID DEST  \
# 56328   2018  2018-01-23              15991    YAK            12523  JNU
# 301885  2018  2018-01-03              12889    LAS            14570  RNO
# 60266   2018  2018-01-31              15991    YAK            12523  JNU
# 303223  2018  2018-01-03              14570    RNO            12889  LAS
# 242437  2018  2018-01-11              11433    DTW            11003  CID
# 223072  2018  2018-01-05              12519    JMS            11447  DVL
# 52411   2018  2018-01-15              15991    YAK            12523  JNU
# 250467  2018  2018-01-26              14150    PLN            10333  APN
# 51441   2018  2018-01-13              15991    YAK            10926  CDV
# 220862  2018  2018-01-20              13241    MEI            14109  PIB
# 51900   2018  2018-01-14              10926    CDV            10299  ANC
# 59775   2018  2018-01-30              15991    YAK            12523  JNU
# 50452   2018  2018-01-11              15991    YAK            12523  JNU
# 243875  2018  2018-01-11              14150    PLN            10333  APN
# 219874  2018  2018-01-19              12519    JMS            11447  DVL
# 53897   2018  2018-01-18              15991    YAK            12523  JNU
# 48940   2018  2018-01-08              12819    KTN            14747  SEA
# 53878   2018  2018-01-18              15991    YAK            10926  CDV
# 53389   2018  2018-01-17              14256    PSG            15841  WRG
# 53379   2018  2018-01-17              10926    CDV            10299  ANC
# 55344   2018  2018-01-21              10926    CDV            15991  YAK
# 232075  2018  2018-01-21              14150    PLN            10333  APN
# 55345   2018  2018-01-21              15991    YAK            12523  JNU
# 59277   2018  2018-01-29              15991    YAK            12523  JNU
# 57821   2018  2018-01-26              14256    PSG            15841  WRG
# 215610  2018  2018-01-17              15454    UIN            10967  CGI
# 52905   2018  2018-01-16              15991    YAK            12523  JNU
# 57832   2018  2018-01-26              10926    CDV            15991  YAK
# 56298   2018  2018-01-23              14709    SCC            10754  BRW
# 58769   2018  2018-01-28              15991    YAK            10926  CDV
# ...      ...         ...                ...    ...              ...  ...
# 560967  2018  2018-01-18              15304    TPA            10397  ATL
# 561023  2018  2018-01-18              10529    BDL            10397  ATL
# 561058  2018  2018-01-18              11057    CLT            10397  ATL
# 561063        NaN        NaN        1.0
# 561073        NaN        NaN        1.0
# 561122        NaN        NaN        1.0
# 561140        NaN        NaN        1.0
# 561259        NaN        NaN        1.0
# 561275        NaN        NaN        1.0
# 561314        NaN        NaN        1.0
# 561315        NaN        NaN        1.0
# 561316        NaN        NaN        1.0
# 561317        NaN        NaN        1.0
# 562487        NaN        NaN        1.0
# 563132        NaN        NaN        1.0
# 563309        NaN        NaN        1.0
# 563481        NaN        NaN        1.0
# 563749        NaN        NaN        1.0
# 563807        NaN        NaN        1.0
# 564067        NaN        NaN        1.0
# 564163        NaN        NaN        1.0
# 564170        NaN        NaN        1.0
# 564173        NaN        NaN        1.0
# 564180        NaN        NaN        1.0
# 564207        NaN        NaN        1.0
# 564383        NaN        NaN        1.0
# 565025        NaN        NaN        1.0
# 565957        NaN        NaN        1.0
# 566427        NaN        NaN        1.0
#
# [570118 rows x 9 columns]

# %%
#Check Dataframe dimensions: number of rows
len(df)
# Out:
# 570118

# %%
#NaN Treatment
df_clean = df.dropna()
df_clean.head()
# Out:
# Empty DataFrame
# Columns: [YEAR, QUARTER, MONTH, DAY_OF_MONTH, DAY_OF_WEEK, FL_DATE, OP_UNIQUE_CARRIER, OP_CARRIER, TAIL_NUM, OP_CARRIER_FL_NUM, ORIGIN_AIRPORT_ID, ORIGIN_CITY_MARKET_ID, ORIGIN, ORIGIN_STATE_ABR, ORIGIN_STATE_NM, ORIGIN_WAC, DEST_AIRPORT_ID, DEST_CITY_MARKET_ID, DEST, DEST_STATE_ABR, DEST_STATE_NM, DEST_WAC, CRS_DEP_TIME, DEP_TIME, DEP_DELAY, DEP_DELAY_NEW, DEP_DEL15, DEP_DELAY_GROUP, CRS_ARR_TIME, ARR_TIME, ARR_DELAY, ARR_DELAY_NEW, ARR_DEL15, ARR_DELAY_GROUP, CANCELLED, CANCELLATION_CODE, DIVERTED, CRS_ELAPSED_TIME, ACTUAL_ELAPSED_TIME, AIR_TIME, FLIGHTS, DISTANCE, DISTANCE_GROUP, CARRIER_DELAY, WEATHER_DELAY, NAS_DELAY, SECURITY_DELAY, LATE_AIRCRAFT_DELAY, Unnamed: 48]
# Index: []
#
# [0 rows x 49 columns]

# %%
df_flights_list_clean = df_flights_list.dropna()
df_flights_list_clean.head()
# Out:
#    YEAR     FL_DATE  ORIGIN_AIRPORT_ID ORIGIN  DEST_AIRPORT_ID DEST  \
# 0  2018  2018-01-27              11697    FLL            12266  IAH
# 1  2018  2018-01-27              14747    SEA            14771  SFO
# 2  2018  2018-01-27              11278    DCA            12266  IAH
# 3  2018  2018-01-27              12892    LAX            13930  ORD
# 4  2018  2018-01-27              12451    JAX            11618  EWR
#
#    DEP_DELAY  ARR_DELAY  CANCELLED
# 0      -13.0      -12.0        0.0
# 1       -4.0      -18.0        0.0
# 2       -2.0        1.0        0.0
# 3       -9.0       -8.0        0.0
# 4      -14.0      -24.0        0.0
